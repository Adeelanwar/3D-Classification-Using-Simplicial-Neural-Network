# %%
from helper_functions.halfedge import *

csv_path = "metadata_modelnet10.csv"
df = pd.read_csv(csv_path)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
root_path = "Data\\Simplified_10_0.5\\"
df['path'] = root_path + df['object_path']

process_all_meshes(df, batch_size=100, output_dir='Data\he_10_05')
# Out:
# Processed 100 out of 4902 meshes
# Processed 200 out of 4902 meshes
# Processed 300 out of 4902 meshes
# Processed 400 out of 4902 meshes
# Processed 500 out of 4902 meshes
# Processed 600 out of 4902 meshes
# Processed 700 out of 4902 meshes
# Processed 800 out of 4902 meshes
# Processed 900 out of 4902 meshes
# Processed 1000 out of 4902 meshes
# Processed 1100 out of 4902 meshes
# Processed 1200 out of 4902 meshes
# Processed 1300 out of 4902 meshes
# Processed 1400 out of 4902 meshes
# Processed 1500 out of 4902 meshes
# Processed 1600 out of 4902 meshes
# Processed 1700 out of 4902 meshes
# Processed 1800 out of 4902 meshes
# Processed 1900 out of 4902 meshes
# Processed 2000 out of 4902 meshes
# Processed 2100 out of 4902 meshes
# Processed 2200 out of 4902 meshes
# Processed 2300 out of 4902 meshes
# Processed 2400 out of 4902 meshes
# Processed 2500 out of 4902 meshes
# Processed 2600 out of 4902 meshes
# Processed 2700 out of 4902 meshes
# Processed 2800 out of 4902 meshes
# ...

# %%
root_path = "Data\\Simplified_10_0.33\\"
df['path'] = root_path + df['object_path']

process_all_meshes(df, batch_size=100, output_dir='Data\he_10_33')
# Out:
# Processed 100 out of 4902 meshes
# Processed 200 out of 4902 meshes
# Processed 300 out of 4902 meshes
# Processed 400 out of 4902 meshes
# Processed 500 out of 4902 meshes
# Processed 600 out of 4902 meshes
# Processed 700 out of 4902 meshes
# Processed 800 out of 4902 meshes
# Processed 900 out of 4902 meshes
# Processed 1000 out of 4902 meshes
# Processed 1100 out of 4902 meshes
# Processed 1200 out of 4902 meshes
# Processed 1300 out of 4902 meshes
# Processed 1400 out of 4902 meshes
# Processed 1500 out of 4902 meshes
# Processed 1600 out of 4902 meshes
# Processed 1700 out of 4902 meshes
# Processed 1800 out of 4902 meshes
# Processed 1900 out of 4902 meshes
# Processed 2000 out of 4902 meshes
# Processed 2100 out of 4902 meshes
# Processed 2200 out of 4902 meshes
# Processed 2300 out of 4902 meshes
# Processed 2400 out of 4902 meshes
# Processed 2500 out of 4902 meshes
# Processed 2600 out of 4902 meshes
# Processed 2700 out of 4902 meshes
# Processed 2800 out of 4902 meshes
# ...

# %%
root_path = "Data\\Simplified_50_0.5\\"
df['path'] = root_path + df['object_path']

process_all_meshes(df, batch_size=100, output_dir='Data\he_50_05')
# Out:
# Processed 100 out of 4902 meshes
# Processed 200 out of 4902 meshes
# Processed 300 out of 4902 meshes
# Processed 400 out of 4902 meshes
# Processed 500 out of 4902 meshes
# Processed 600 out of 4902 meshes
# Processed 700 out of 4902 meshes
# Processed 800 out of 4902 meshes
# Processed 900 out of 4902 meshes
# Processed 1000 out of 4902 meshes
# Processed 1100 out of 4902 meshes
# Processed 1200 out of 4902 meshes
# Processed 1300 out of 4902 meshes
# Processed 1400 out of 4902 meshes
# Processed 1500 out of 4902 meshes
# Processed 1600 out of 4902 meshes
# Processed 1700 out of 4902 meshes
# Processed 1800 out of 4902 meshes
# Processed 1900 out of 4902 meshes
# Processed 2000 out of 4902 meshes
# Processed 2100 out of 4902 meshes
# Processed 2200 out of 4902 meshes
# Processed 2300 out of 4902 meshes
# Processed 2400 out of 4902 meshes
# Processed 2500 out of 4902 meshes
# Processed 2600 out of 4902 meshes
# Processed 2700 out of 4902 meshes
# Processed 2800 out of 4902 meshes
# ...

# %%
root_path = "Data\\Simplified_25_0.33\\"
df['path'] = root_path + df['object_path']

process_all_meshes(df, batch_size=100, output_dir='Data\he_25_33')
# Out:
# Processed 100 out of 4902 meshes
# Processed 200 out of 4902 meshes
# Processed 300 out of 4902 meshes
# Processed 400 out of 4902 meshes
# Processed 500 out of 4902 meshes
# Processed 600 out of 4902 meshes
# Processed 700 out of 4902 meshes
# Processed 800 out of 4902 meshes
# Processed 900 out of 4902 meshes
# Processed 1000 out of 4902 meshes
# Processed 1100 out of 4902 meshes
# Processed 1200 out of 4902 meshes
# Processed 1300 out of 4902 meshes
# Processed 1400 out of 4902 meshes
# Processed 1500 out of 4902 meshes
# Processed 1600 out of 4902 meshes
# Processed 1700 out of 4902 meshes
# Processed 1800 out of 4902 meshes
# Processed 1900 out of 4902 meshes
# Processed 2000 out of 4902 meshes
# Processed 2100 out of 4902 meshes
# Processed 2200 out of 4902 meshes
# Processed 2300 out of 4902 meshes
# Processed 2400 out of 4902 meshes
# Processed 2500 out of 4902 meshes
# Processed 2600 out of 4902 meshes
# Processed 2700 out of 4902 meshes
# Processed 2800 out of 4902 meshes
# ...

# %%
root_path = "Data\\Simplified_25_0.5\\"
df['path'] = root_path + df['object_path']

process_all_meshes(df, batch_size=100, output_dir='Data\he_25_05')
# Out:
# Processed 100 out of 4902 meshes
# Processed 200 out of 4902 meshes
# Processed 300 out of 4902 meshes
# Processed 400 out of 4902 meshes
# Processed 500 out of 4902 meshes
# Processed 600 out of 4902 meshes
# Processed 700 out of 4902 meshes
# Processed 800 out of 4902 meshes
# Processed 900 out of 4902 meshes
# Processed 1000 out of 4902 meshes
# Processed 1100 out of 4902 meshes
# Processed 1200 out of 4902 meshes
# Processed 1300 out of 4902 meshes
# Processed 1400 out of 4902 meshes
# Processed 1500 out of 4902 meshes
# Processed 1600 out of 4902 meshes
# Processed 1700 out of 4902 meshes
# Processed 1800 out of 4902 meshes
# Processed 1900 out of 4902 meshes
# Processed 2000 out of 4902 meshes
# Processed 2100 out of 4902 meshes
# Processed 2200 out of 4902 meshes
# Processed 2300 out of 4902 meshes
# Processed 2400 out of 4902 meshes
# Processed 2500 out of 4902 meshes
# Processed 2600 out of 4902 meshes
# Processed 2700 out of 4902 meshes
# Processed 2800 out of 4902 meshes
# ...
