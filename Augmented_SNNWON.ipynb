# %%
import warnings
warnings.filterwarnings('ignore')

from helper_functions.train_funcs_4f_vertex import *

# %%
train_multiple_datasets(root_paths=['he_25_05/','he_25_33/','he_10_05/','he_10_33/'], hidden_dim=64, batch_size=16, lr=0.02, weight_decay=1e-5, num_epochs=75,residual_connections=True, save_path=None,dropout_rate=0.3, use_ema=False, use_batch_norm=True,lr_min=0.0005,lr_max=0.01, label_smoothing=0, log_file='_100_Enhanced_SNN.csv')
# Out:
# Using device: cuda
# Epoch 1/75 - Current LR: 0.020000
# Epoch 1/75:
#   Train Loss: 0.9803, Train Acc: 0.6132
#   Val Loss: 64.4695, Val Acc: 0.6925
# New best model saved to Saved/Augmented_SNNWOC_hd64_lr0.02_wd1e-05_epochs75_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.6925
# Epoch 2/75 - Current LR: 0.019991
# Epoch 2/75:
#   Train Loss: 0.4937, Train Acc: 0.7039
#   Val Loss: 32.5105, Val Acc: 0.7503
# New best model saved to Saved/Augmented_SNNWOC_hd64_lr0.02_wd1e-05_epochs75_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7503
# Epoch 3/75 - Current LR: 0.019966
# Epoch 3/75:
#   Train Loss: 0.4294, Train Acc: 0.7393
#   Val Loss: 2.2195, Val Acc: 0.7302
# Epoch 4/75 - Current LR: 0.019923
# Epoch 4/75:
#   Train Loss: 0.4116, Train Acc: 0.7477
#   Val Loss: 0.3320, Val Acc: 0.7671
# New best model saved to Saved/Augmented_SNNWOC_hd64_lr0.02_wd1e-05_epochs75_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7671
# Epoch 5/75 - Current LR: 0.019863
# Epoch 5/75:
# ...
