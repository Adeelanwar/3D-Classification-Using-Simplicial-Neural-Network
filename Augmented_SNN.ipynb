# %%
import warnings
warnings.filterwarnings('ignore')

from helper_functions.train_funcs import *

# %%
train_multiple_datasets(root_paths=['he_50_33/','he_50_05/'], batch_size=16, lr=0.005, weight_decay=1e-5, num_epochs=30, save_path=None,dropout_rate=0.3, use_ema=False, use_batch_norm=True,lr_min=0.0001,lr_max=0.01, label_smoothing=0, log_file='Enhanced_SNN.csv')
# Out:
# Using device: cuda
# Epoch 1/30 - Current LR: 0.005000
# Epoch 1/30:
#   Train Loss: 2.6518, Train Acc: 0.4470
#   Val Loss: 0.7810, Val Acc: 0.5931
# New best model saved to Saved/Augmented_SNN_hd64_lr0.005_wd1e-05_epochs30_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.5931
# Epoch 2/30 - Current LR: 0.004987
# Epoch 2/30:
#   Train Loss: 0.6523, Train Acc: 0.6508
#   Val Loss: 0.4816, Val Acc: 0.6960
# New best model saved to Saved/Augmented_SNN_hd64_lr0.005_wd1e-05_epochs30_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.6960
# Epoch 3/30 - Current LR: 0.004946
# Epoch 3/30:
#   Train Loss: 0.4848, Train Acc: 0.7176
#   Val Loss: 0.4207, Val Acc: 0.7500
# New best model saved to Saved/Augmented_SNN_hd64_lr0.005_wd1e-05_epochs30_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7500
# Epoch 4/30 - Current LR: 0.004880
# Epoch 4/30:
#   Train Loss: 0.4025, Train Acc: 0.7543
#   Val Loss: 0.3983, Val Acc: 0.7599
# ...

# %%
train_multiple_datasets(root_paths=['he_25_33/','he_25_05/'], batch_size=16, lr=0.006, weight_decay=1e-5, num_epochs=30, save_path=None,dropout_rate=0.3, use_ema=False, use_batch_norm=True,lr_min=0.0001,lr_max=0.01, label_smoothing=0, log_file='Enhanced_SNN.csv')
# Out:
# Using device: cuda
# Epoch 1/30 - Current LR: 0.006000
# Epoch 1/30:
#   Train Loss: 2.4126, Train Acc: 0.4696
#   Val Loss: 0.6811, Val Acc: 0.6068
# New best model saved to Saved/Augmented_SNN_hd64_lr0.006_wd1e-05_epochs30_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.6068
# Epoch 2/30 - Current LR: 0.005984
# Epoch 2/30:
#   Train Loss: 0.5763, Train Acc: 0.6770
#   Val Loss: 0.4283, Val Acc: 0.7401
# New best model saved to Saved/Augmented_SNN_hd64_lr0.006_wd1e-05_epochs30_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7401
# Epoch 3/30 - Current LR: 0.005936
# Epoch 3/30:
#   Train Loss: 0.4425, Train Acc: 0.7286
#   Val Loss: 0.3679, Val Acc: 0.7654
# New best model saved to Saved/Augmented_SNN_hd64_lr0.006_wd1e-05_epochs30_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7654
# Epoch 4/30 - Current LR: 0.005856
# Epoch 4/30:
#   Train Loss: 0.3681, Train Acc: 0.7627
#   Val Loss: 0.3439, Val Acc: 0.7528
# Epoch 5/30 - Current LR: 0.005745
# Epoch 5/30:
# ...

# %%
train_multiple_datasets(root_paths=['he_10_33/','he_10_05/'], batch_size=16, lr=0.01, weight_decay=1e-5, num_epochs=50, save_path=None,dropout_rate=0.3, use_ema=False, use_batch_norm=True,lr_min=0.0001,lr_max=0.01, label_smoothing=0, log_file='_50_Enhanced_SNN.csv')
# Out:
# Using device: cuda
# Epoch 1/50 - Current LR: 0.010000
# Epoch 1/50:
#   Train Loss: 1.8733, Train Acc: 0.5215
#   Val Loss: 132.7665, Val Acc: 0.7258
# New best model saved to Saved/Augmented_SNN_hd64_lr0.01_wd1e-05_epochs50_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7258
# Epoch 2/50 - Current LR: 0.009990
# Epoch 2/50:
#   Train Loss: 0.5226, Train Acc: 0.6968
#   Val Loss: 89.9515, Val Acc: 0.7461
# New best model saved to Saved/Augmented_SNN_hd64_lr0.01_wd1e-05_epochs50_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7461
# Epoch 3/50 - Current LR: 0.009961
# Epoch 3/50:
#   Train Loss: 0.4203, Train Acc: 0.7456
#   Val Loss: 13.8222, Val Acc: 0.7819
# New best model saved to Saved/Augmented_SNN_hd64_lr0.01_wd1e-05_epochs50_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7819
# Epoch 4/50 - Current LR: 0.009912
# Epoch 4/50:
#   Train Loss: 0.3575, Train Acc: 0.7671
#   Val Loss: 0.3113, Val Acc: 0.7913
# ...

# %%
train_multiple_datasets(root_paths=['he_25_33/','he_10_33/','he_10_05/'], hidden_dim=96, batch_size=16, lr=0.01, weight_decay=1e-5, num_epochs=50, save_path=None,dropout_rate=0.3, use_ema=False, use_batch_norm=True,lr_min=0.0001,lr_max=0.01, label_smoothing=0, log_file='_50_Enhanced_SNN.csv')
# Out:
# Using device: cuda
# Epoch 1/50 - Current LR: 0.010000
# Epoch 1/50:
#   Train Loss: 1.3098, Train Acc: 0.5925
#   Val Loss: 79.5106, Val Acc: 0.7346
# New best model saved to Saved/Augmented_SNN_hd96_lr0.01_wd1e-05_epochs50_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7346
# Epoch 2/50 - Current LR: 0.009990
# Epoch 2/50:
#   Train Loss: 0.4339, Train Acc: 0.7418
#   Val Loss: 82.2355, Val Acc: 0.7757
# New best model saved to Saved/Augmented_SNN_hd96_lr0.01_wd1e-05_epochs50_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7757
# Epoch 3/50 - Current LR: 0.009961
# Epoch 3/50:
#   Train Loss: 0.3627, Train Acc: 0.7767
#   Val Loss: 57.3750, Val Acc: 0.7974
# New best model saved to Saved/Augmented_SNN_hd96_lr0.01_wd1e-05_epochs50_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7974
# Epoch 4/50 - Current LR: 0.009912
# Epoch 4/50:
#   Train Loss: 0.3268, Train Acc: 0.7941
#   Val Loss: 64.4130, Val Acc: 0.8275
# ...

# %%
train_multiple_datasets(root_paths=['he_25_05/','he_25_33/','he_10_33/','he_10_05/'], hidden_dim=96, batch_size=16, lr=0.01, weight_decay=1e-5, num_epochs=60, save_path=None,dropout_rate=0.3, use_ema=False, use_batch_norm=True,lr_min=0.0005,lr_max=0.01, label_smoothing=0, log_file='_50_Enhanced_SNN.csv')
# Out:
# Using device: cuda
# Epoch 1/60 - Current LR: 0.010000
# Epoch 1/60:
#   Train Loss: 1.1102, Train Acc: 0.6237
#   Val Loss: 24.7202, Val Acc: 0.7423
# New best model saved to Saved/Augmented_SNN_hd96_lr0.01_wd1e-05_epochs60_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7423
# Epoch 2/60 - Current LR: 0.009993
# Epoch 2/60:
#   Train Loss: 0.3944, Train Acc: 0.7549
#   Val Loss: 1.2991, Val Acc: 0.7946
# New best model saved to Saved/Augmented_SNN_hd96_lr0.01_wd1e-05_epochs60_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7946
# Epoch 3/60 - Current LR: 0.009974
# Epoch 3/60:
#   Train Loss: 0.3225, Train Acc: 0.7940
#   Val Loss: 0.2860, Val Acc: 0.8018
# New best model saved to Saved/Augmented_SNN_hd96_lr0.01_wd1e-05_epochs60_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.8018
# Epoch 4/60 - Current LR: 0.009942
# Epoch 4/60:
#   Train Loss: 0.3061, Train Acc: 0.8000
#   Val Loss: 0.2589, Val Acc: 0.8238
# ...

# %%
train_multiple_datasets(root_paths=['he_50_33/','he_25_33/','he_10_33/'], hidden_dim=64, batch_size=16, lr=0.015, weight_decay=1e-5, num_epochs=35, save_path=None,dropout_rate=0.3, use_ema=False, use_batch_norm=True,lr_min=0.001,lr_max=0.01, label_smoothing=0, log_file='_3_50_Enhanced_SNN.csv')
# Out:
# Using device: cuda
# Epoch 1/35 - Current LR: 0.015000
# Epoch 1/35:
#   Train Loss: 1.3437, Train Acc: 0.5490
#   Val Loss: 49.8892, Val Acc: 0.6637
# New best model saved to Saved/Augmented_SNN_hd64_lr0.015_wd1e-05_epochs35_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.6637
# Epoch 2/35 - Current LR: 0.014972
# Epoch 2/35:
#   Train Loss: 0.5517, Train Acc: 0.6780
#   Val Loss: 36.5350, Val Acc: 0.6960
# New best model saved to Saved/Augmented_SNN_hd64_lr0.015_wd1e-05_epochs35_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.6960
# Epoch 3/35 - Current LR: 0.014888
# Epoch 3/35:
#   Train Loss: 0.4617, Train Acc: 0.7244
#   Val Loss: 17.5901, Val Acc: 0.7860
# New best model saved to Saved/Augmented_SNN_hd64_lr0.015_wd1e-05_epochs35_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7860
# Epoch 4/35 - Current LR: 0.014748
# Epoch 4/35:
#   Train Loss: 0.4247, Train Acc: 0.7427
#   Val Loss: 0.4041, Val Acc: 0.7236
# Epoch 5/35 - Current LR: 0.014554
# Epoch 5/35:
# ...

# %%
train_multiple_datasets(root_paths=['he_10_33/','he_10_05/'], hidden_dim=128, batch_size=16, lr=0.01, weight_decay=1e-5, num_epochs=100,residual_connections=True, save_path=None,dropout_rate=0.3, use_ema=False, use_batch_norm=True,lr_min=0.0005,lr_max=0.01, label_smoothing=0, log_file='_100_Enhanced_SNN.csv')
# Out:
# Using device: cuda
# Epoch 1/100 - Current LR: 0.010000
# Epoch 1/100:
#   Train Loss: 1.6529, Train Acc: 0.5709
#   Val Loss: 113.8455, Val Acc: 0.7450
# New best model saved to Saved/Augmented_SNN_hd128_lr0.01_wd1e-05_epochs100_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7450
# Epoch 2/100 - Current LR: 0.009998
# Epoch 2/100:
#   Train Loss: 0.4513, Train Acc: 0.7382
#   Val Loss: 0.2899, Val Acc: 0.7974
# New best model saved to Saved/Augmented_SNN_hd128_lr0.01_wd1e-05_epochs100_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.7974
# Epoch 3/100 - Current LR: 0.009991
# Epoch 3/100:
#   Train Loss: 0.3675, Train Acc: 0.7702
#   Val Loss: 0.2818, Val Acc: 0.8150
# New best model saved to Saved/Augmented_SNN_hd128_lr0.01_wd1e-05_epochs100_seed42_bs16_drop0.3_bn1_best.pt with val acc: 0.8150
# Epoch 4/100 - Current LR: 0.009979
# Epoch 4/100:
#   Train Loss: 0.3071, Train Acc: 0.8014
#   Val Loss: 0.2668, Val Acc: 0.8309
# ...
